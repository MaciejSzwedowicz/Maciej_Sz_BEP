# %%
# ✅ Notebook Goal:
# Use the field presence CSVs to verify which fields are populated in both SQLite and MongoDB

import pandas as pd
import pymongo
import sqlite3

# --- Load CSV Files ---
value_fields = pd.read_csv("../../reports/evaluation_results/value_fields_presence.csv")
object_fields = pd.read_csv("../../reports/evaluation_results/object_fields_presence.csv")

# --- MongoDB Setup ---
mongo_client = pymongo.MongoClient("mongodb://localhost:27017/")
mongo_collection = mongo_client["openfda_converted"]["full_reports"]

# --- SQLite Setup ---
sqlite_conn = sqlite3.connect("../../sql/openfda_base_updated.db")

# %%
# --- 1. Field Presence in MongoDB ---
def count_field_presence_mongo(field):
    return mongo_collection.count_documents({field: {"$exists": True}})

print("\n🔍 MongoDB - Value Field Presence")
for field in value_fields["field_path"]:
    count = count_field_presence_mongo(field)
    print(f"{field}: {count} documents")

print("\n📦 MongoDB - Object Field Presence")
for field in object_fields["field_path"]:
    count = count_field_presence_mongo(field)
    print(f"{field}: {count} documents")
# Out:
# 🔍 MongoDB - Value Field Presence
# authoritynumb: 3793 documents
# companynumb: 32084 documents
# duplicate: 11714 documents
# fulfillexpeditecriteria: 35999 documents
# occurcountry: 33456 documents
# patient.drug.actiondrug: 34484 documents
# patient.drug.activesubstance.activesubstancename: 35999 documents
# patient.drug.drugadditional: 28116 documents
# patient.drug.drugadministrationroute: 30832 documents
# patient.drug.drugauthorizationnumb: 33368 documents
# patient.drug.drugbatchnumb: 15417 documents
# patient.drug.drugcharacterization: 35999 documents
# patient.drug.drugcumulativedosagenumb: 1348 documents
# patient.drug.drugcumulativedosageunit: 1348 documents
# patient.drug.drugdosageform: 28649 documents
# patient.drug.drugdosagetext: 29863 documents
# patient.drug.drugenddate: 8429 documents
# patient.drug.drugenddateformat: 8429 documents
# patient.drug.drugindication: 34014 documents
# patient.drug.drugintervaldosagedefinition: 17594 documents
# patient.drug.drugintervaldosageunitnumb: 17594 documents
# patient.drug.drugrecurreadministration: 4658 documents
# patient.drug.drugseparatedosagenumb: 18331 documents
# patient.drug.drugstartdate: 18032 documents
# patient.drug.drugstartdateformat: 18032 documents
# patient.drug.drugstructuredosagenumb: 23460 documents
# patient.drug.drugstructuredosageunit: 23423 documents
# patient.drug.drugtreatmentduration: 6210 documents
# patient.drug.drugtreatmentdurationunit: 6210 documents
# patient.drug.medicinalproduct: 35999 documents
# patient.drug.openfda.application_number: 35659 documents
# patient.drug.openfda.brand_name: 35665 documents
# patient.drug.openfda.generic_name: 35665 documents
# patient.drug.openfda.manufacturer_name: 35665 documents
# patient.drug.openfda.nui: 29362 documents
# patient.drug.openfda.package_ndc: 35665 documents
# patient.drug.openfda.pharm_class_cs: 15159 documents
# patient.drug.openfda.pharm_class_epc: 29094 documents
# patient.drug.openfda.pharm_class_moa: 24807 documents
# patient.drug.openfda.pharm_class_pe: 7550 documents
# patient.drug.openfda.product_ndc: 35665 documents
# patient.drug.openfda.product_type: 35665 documents
# patient.drug.openfda.route: 34697 documents
# patient.drug.openfda.rxcui: 31011 documents
# patient.drug.openfda.spl_id: 35665 documents
# patient.drug.openfda.spl_set_id: 35665 documents
# patient.drug.openfda.substance_name: 34688 documents
# patient.drug.openfda.unii: 34701 documents
# patient.patientagegroup: 12194 documents
# patient.patientonsetage: 23541 documents
# patient.patientonsetageunit: 23543 documents
# patient.patientsex: 30955 documents
# patient.patientweight: 6874 documents
# patient.reaction.reactionmeddrapt: 35999 documents
# patient.reaction.reactionmeddraversionpt: 35999 documents
# patient.reaction.reactionoutcome: 34686 documents
# patient.summary.narrativeincludeclinical: 16948 documents
# primarysource.literaturereference: 3309 documents
# primarysource.qualification: 35781 documents
# primarysource.reportercountry: 35999 documents
# primarysourcecountry: 35856 documents
# receiptdate: 35999 documents
# receiptdateformat: 35999 documents
# receivedate: 35999 documents
# receivedateformat: 35999 documents
# receiver.receiverorganization: 35999 documents
# receiver.receivertype: 35999 documents
# reportduplicate.duplicatenumb: 11556 documents
# reportduplicate.duplicatesource: 11464 documents
# reporttype: 35974 documents
# safetyreportid: 35999 documents
# safetyreportversion: 35999 documents
# sender.senderorganization: 35999 documents
# sender.sendertype: 35999 documents
# serious: 35999 documents
# seriousnesscongenitalanomali: 34706 documents
# seriousnessdeath: 34823 documents
# seriousnessdisabling: 34717 documents
# seriousnesshospitalization: 35163 documents
# seriousnesslifethreatening: 34846 documents
# seriousnessother: 35215 documents
# transmissiondate: 35999 documents
# transmissiondateformat: 35999 documents
#
# 📦 MongoDB - Object Field Presence
# patient: 35999 documents
# patient.drug: 35999 documents
# patient.drug.activesubstance: 35999 documents
# patient.drug.openfda: 35670 documents
# patient.reaction: 35999 documents
# patient.summary: 16948 documents
# primarysource: 35999 documents
# receiver: 35999 documents
# reportduplicate: 11561 documents
# sender: 35999 documents

# %%
# # --- 2. Field Presence in SQLite ---
# print("\n🧱 SQLite - Table Column Coverage")
# def count_not_null(conn, table, column):
#     try:
#         df = pd.read_sql_query(f"SELECT COUNT(*) as cnt FROM {table} WHERE {column} IS NOT NULL", conn)
#         return df["cnt"].iloc[0]
#     except Exception as e:
#         return f"Error: {str(e)}"

# # Value fields are stored as table.column format
# print("\nSQLite - Checking column presence")
# value_fields_split = value_fields["field_path"].str.extract(r"(?P<table>\w+)\.(?P<column>\w+)")
# value_fields = pd.concat([value_fields, value_fields_split], axis=1)

# for _, row in value_fields.iterrows():
#     table, column = row["table"], row["column"]
#     result = count_not_null(sqlite_conn, table, column)
#     print(f"{table}.{column}: {result} non-null rows")

# %%
# Cleanup
sqlite_conn.close()
mongo_client.close()
