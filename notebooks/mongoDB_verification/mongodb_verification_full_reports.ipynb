# %% [markdown]
# # MongoDB Data Verification – Converted OpenFDA Database
# This notebook verifies the field conversions and data integrity in the MongoDB collection `full_reports`.

# %%
import pymongo
from bson import json_util
from pprint import pprint

# Connect to MongoDB
client = pymongo.MongoClient("mongodb://localhost:27017")
db = client["openfda_converted"]
collection = db["full_reports"]

# %% [markdown]
# ## 1. Check total number of inserted reports

# %%
total_reports = collection.count_documents({})
print(f"Total inserted reports: {total_reports}")
# Out:
# Total inserted reports: 35999

# %% [markdown]
# ## 2. Verify integer fields

# %%
query = {"safetyreportversion": {"$type": "int"}}
docs = list(collection.find(query).limit(5))
for doc in docs:
    pprint(doc)
# Out:
# {'_id': ObjectId('68246feda116cc7161242716'),
#  'companynumb': 'US-SECURA BIO, INC.-2021US002331',
#  'fulfillexpeditecriteria': 2,
#  'occurcountry': 'US',
#  'patient': {'drug': [{'actiondrug': 5,
#                        'activesubstance': {'activesubstancename': 'DUVELISIB'},
#                        'drugadditional': 3,
#                        'drugadministrationroute': 48,
#                        'drugauthorizationnumb': 211155,
#                        'drugbatchnumb': '1697765A',
#                        'drugcharacterization': 1,
#                        'drugdosageform': 'Capsule',
#                        'drugdosagetext': '75 MG, BID',
#                        'drugindication': 'Non-Hodgkin^s lymphoma',
#                        'drugintervaldosagedefinition': 804,
#                        'drugintervaldosageunitnumb': 1.0,
#                        'drugrecurreadministration': 3,
#                        'drugseparatedosagenumb': 2.0,
#                        'drugstructuredosagenumb': 75.0,
#                        'drugstructuredosageunit': 3,
#                        'medicinalproduct': 'COPIKTRA',
#                        'openfda': {'application_number': ['NDA211155'],
#                                    'brand_name': ['COPIKTRA'],
#                                    'generic_name': ['DUVELISIB'],
#                                    'manufacturer_name': ['Secura Bio, Inc'],
#                                    'package_ndc': ['73116-225-28',
#                                                    '73116-225-56',
#                                                    '73116-215-28',
#                                                    '73116-215-56'],
#                                    'product_ndc': ['73116-215', '73116-225'],
#                                    'product_type': ['HUMAN PRESCRIPTION DRUG'],
#                                    'route': ['ORAL'],
#                                    'rxcui': ['2058514',
#                                              '2058520',
#                                              '2058523',
#                                              '2058525'],
#                                    'spl_id': ['de5c746e-bd30-4b3c-a473-b8fe1f70153c'],
#                                    'spl_set_id': ['e3c5ac56-e1f6-473a-bc73-687836534780'],
#                                    'substance_name': ['DUVELISIB'],
#                                    'unii': ['610V23S0JI']}},
#                       {'actiondrug': 5,
#                        'activesubstance': {'activesubstancename': 'AMLODIPINE '
#                                                                   'BESYLATE'},
#                        'drugadditional': 3,
#                        'drugadministrationroute': 65,
#                        'drugcharacterization': 1,
#                        'drugindication': 'Product used for unknown indication',
#                        'drugrecurreadministration': 3,
#                        'medicinalproduct': 'AMLODIPINE',
#                        'openfda': {'application_number': ['NDA214439',
#                                                           'NDA211340',
#                                                           'ANDA215035'],
#                                    'brand_name': ['NORLIQVA',
#                                                   'KATERZIA',
#                                                   'AMLODIPINE'],
#                                    'generic_name': ['AMLODIPINE'],
#                                    'manufacturer_name': ['CMP Pharma, Inc.',
#                                                          'Azurity '
#                                                          'Pharmaceuticals, '
#                                                          'Inc.',
#                                                          'Amneal '
#                                                          'Pharmaceuticals NY '
#                                                          'LLC'],
#                                    'nui': ['N0000000069',
#                                            'N0000175421',
#                                            'N0000175566',
#                                            'M0006414',
#                                            'N0000190114'],
#                                    'package_ndc': ['46287-035-15',
#                                                    '52652-5001-1',
#                                                    '69238-2026-7'],
#                                    'pharm_class_cs': ['Dihydropyridines [CS]'],
#                                    'pharm_class_epc': ['Dihydropyridine '
#                                                        'Calcium Channel '
#                                                        'Blocker [EPC]',
#                                                        'Calcium Channel '
#                                                        'Blocker [EPC]'],
#                                    'pharm_class_moa': ['Calcium Channel '
#                                                        'Antagonists [MoA]',
#                                                        'Cytochrome P450 3A '
#                                                        'Inhibitors [MoA]'],
#                                    'product_ndc': ['46287-035',
#                                                    '52652-5001',
#                                                    '69238-2026'],
#                                    'product_type': ['HUMAN PRESCRIPTION DRUG'],
#                                    'route': ['ORAL'],
#                                    'rxcui': ['2599173',
#                                              '2599179',
#                                              '2184120',
#                                              '2184126'],
#                                    'spl_id': ['63a6bb49-fb68-4351-be5f-a6b6e8f6b540',
#                                               '78965c75-1ba7-48f0-bc14-029d5bb34f88',
#                                               'f18fa3f2-2d8f-499f-9708-3748fee89eb3'],
#                                    'spl_set_id': ['c1730a51-4383-4c61-a9a1-7e1326bd0abe',
#                                                   'df673a4d-acb8-444c-a472-c87ab8cbd366',
#                                                   '8394e577-3b64-4655-86b8-b757126672c9'],
#                                    'substance_name': ['AMLODIPINE',
#                                                       'AMLODIPINE BENZOATE'],
#                                    'unii': ['1J444QC288', 'XD75TQ8A2P']}}],
#              'reaction': [{'reactionmeddrapt': 'Fatigue',
#                            'reactionmeddraversionpt': 26.1,
#                            'reactionoutcome': 6},
#                           {'reactionmeddrapt': 'Constipation',
#                            'reactionmeddraversionpt': 26.1,
#                            'reactionoutcome': 6},
#                           {'reactionmeddrapt': 'Dyspnoea',
#                            'reactionmeddraversionpt': 26.1,
#                            'reactionoutcome': 6},
#                           {'reactionmeddrapt': 'Blood sodium decreased',
#                            'reactionmeddraversionpt': 26.1,
#                            'reactionoutcome': 6},
#                           {'reactionmeddrapt': 'Hypotension',
#                            'reactionmeddraversionpt': 26.1,
#                            'reactionoutcome': 6},
#                           {'reactionmeddrapt': 'Drug interaction',
#                            'reactionmeddraversionpt': 26.1,
#                            'reactionoutcome': 6}]},
#  'primarysource': {'qualification': 5, 'reportercountry': 'US'},
#  'primarysourcecountry': 'US',
#  'receiptdate': datetime.datetime(2024, 3, 15, 0, 0),
#  'receiptdateformat': 102,
#  'receivedate': datetime.datetime(2021, 7, 12, 0, 0),
#  'receivedateformat': 102,
#  'receiver': {'receiverorganization': 'FDA', 'receivertype': 6},
#  'reporttype': 1,
#  'safetyreportid': 19520083,
#  'safetyreportversion': 2,
#  'sender': {'senderorganization': 'FDA-Public Use', 'sendertype': 2},
#  'serious': 2,
#  'seriousnesscongenitalanomali': 2,
#  'seriousnessdeath': 2,
#  'seriousnessdisabling': 2,
#  'seriousnesshospitalization': 2,
#  'seriousnesslifethreatening': 2,
#  'seriousnessother': 2,
#  'transmissiondate': datetime.datetime(2024, 4, 10, 0, 0),
#  'transmissiondateformat': 102}
# {'_id': ObjectId('68246feda116cc7161242717'),
#  'companynumb': 'DE-PFIZER INC-2021817569',
#  'duplicate': 1,
#  'fulfillexpeditecriteria': 1,
#  'occurcountry': 'DE',
#  'patient': {'drug': [{'actiondrug': 6,
#                        'activesubstance': {'activesubstancename': 'BEVACIZUMAB'},
#                        'drugadditional': 4,
#                        'drugauthorizationnumb': 761099,
#                        'drugcharacterization': 1,
#                        'drugdosagetext': '15 MG/KG OVER 90 MINUTES',
#                        'drugindication': 'Hepatocellular carcinoma',
#                        'drugstructuredosagenumb': 15.0,
#                        'drugstructuredosageunit': 7,
#                        'medicinalproduct': 'BEVACIZUMAB',
#                        'openfda': {'application_number': ['BLA761198',
#                                                           'BLA125085'],
#                                    'brand_name': ['AVZIVI TNJN', 'AVASTIN'],
#                                    'generic_name': ['BEVACIZUMAB'],
#                                    'manufacturer_name': ['Bio-Thera Solutions, '
#                                                          'Ltd.',
#                                                          'Genentech, Inc.'],
#                                    'nui': ['N0000193543',
#                                            'N0000178291',
#                                            'N0000193542'],
#                                    'package_ndc': ['82143-001-01',
#                                                    '82143-002-01',
#                                                    '50242-060-01',
#                                                    '50242-060-10',
#                                                    '50242-061-01',
#                                                    '50242-061-10'],
#                                    'pharm_class_epc': ['Vascular Endothelial '
#                                                        'Growth Factor '
#                                                        'Inhibitor [EPC]'],
#                                    'pharm_class_moa': ['Vascular Endothelial '
#                                                        'Growth Factor-directed '
#                                                        'Antibody Interactions '
#                                                        '[MoA]',
#                                                        'Vascular Endothelial '
#                                                        'Growth Factor '
#                                                        'Inhibitors [MoA]'],
#                                    'product_ndc': ['82143-001',
#                                                    '82143-002',
#                                                    '50242-060',
#                                                    '50242-061'],
#                                    'product_type': ['HUMAN PRESCRIPTION DRUG'],
#                                    'route': ['INTRAVENOUS'],
#                                    'rxcui': ['2700735',
#                                              '2700742',
#                                              '2700744',
#                                              '2700745',
#                                              '1657066',
#                                              '1657068',
#                                              '1657073',
#                                              '1657074'],
#                                    'spl_id': ['24041767-230c-9a58-e063-6394a90ad576',
#                                               '8debebf6-af94-4ba7-8d67-c801f4ea27eb'],
#                                    'spl_set_id': ['a3976cf9-9edb-4ca2-9375-9bcd2e32f5b4',
#                                                   '939b5d1f-9fb2-4499-80ef-0607aa6b114e'],
#                                    'substance_name': ['BEVACIZUMAB-TNJN',
#                                                       'BEVACIZUMAB'],
#                                    'unii': ['2S9ZZM9Q9V']}},
#                       {'actiondrug': 6,
#                        'activesubstance': {'activesubstancename': 'ATEZOLIZUMAB'},
#                        'drugadditional': 4,
#                        'drugcharacterization': 1,
#                        'drugdosagetext': '1200 MG, OVER 2 HOURS',
#                        'drugindication': 'Hepatocellular carcinoma',
#                        'drugstructuredosagenumb': 1200.0,
#                        'drugstructuredosageunit': 3,
#                        'medicinalproduct': 'ATEZOLIZUMAB',
#                        'openfda': {'application_number': ['BLA761034'],
#                                    'brand_name': ['TECENTRIQ'],
#                                    'generic_name': ['ATEZOLIZUMAB'],
#                                    'manufacturer_name': ['Genentech, Inc.'],
#                                    'nui': ['N0000191260',
#                                            'N0000191259',
#                                            'M0556300',
#                                            'M0001357',
#                                            'M0001352'],
#                                    'package_ndc': ['50242-917-01',
#                                                    '50242-917-86',
#                                                    '50242-918-01'],
#                                    'pharm_class_cs': ['Antibodies, Monoclonal, '
#                                                       'Humanized [CS]',
#                                                       'Antibodies, Monoclonal '
#                                                       '[CS]',
#                                                       'Antibodies [CS]'],
#                                    'pharm_class_epc': ['Programmed Death '
#                                                        'Receptor-1 Blocking '
#                                                        'Antibody [EPC]'],
#                                    'pharm_class_moa': ['Programmed Death '
#                                                        'Receptor-1-directed '
#                                                        'Antibody Interactions '
#                                                        '[MoA]'],
#                                    'product_ndc': ['50242-917', '50242-918'],
#                                    'product_type': ['HUMAN PRESCRIPTION DRUG'],
#                                    'route': ['INTRAVENOUS'],
#                                    'rxcui': ['1792780',
#                                              '1792785',
#                                              '2119695',
#                                              '2119696'],
#                                    'spl_id': ['f4fe4626-4d6c-4c50-9d52-51aae17f27d6'],
#                                    'spl_set_id': ['6fa682c9-a312-4932-9831-f286908660ee'],
#                                    'substance_name': ['ATEZOLIZUMAB'],
#                                    'unii': ['52CMI0WC3Y']}}],
#              'patientonsetage': 70,
#              'patientonsetageunit': 801,
#              'patientsex': 2,
#              'reaction': [{'reactionmeddrapt': 'Encephalitis',
#                            'reactionmeddraversionpt': 26.1,
#                            'reactionoutcome': 5},
#                           {'reactionmeddrapt': 'Neurological symptom',
#                            'reactionmeddraversionpt': 26.1,
#                            'reactionoutcome': 5},
#                           {'reactionmeddrapt': 'Multiple organ dysfunction '
#                                                'syndrome',
#                            'reactionmeddraversionpt': 26.1,
#                            'reactionoutcome': 5},
#                           {'reactionmeddrapt': 'Off label use',
#                            'reactionmeddraversionpt': 26.1,
#                            'reactionoutcome': 6}]},
#  'primarysource': {'literaturereference': 'Ozdirik, B.. Atezolizumab and '
#                                           'bevacizumab-induced encephalitis in '
#                                           'advanced hepatocellular carcinoma: '
#                                           'Case report and literature review.. '
#                                           'Medicine. 2021;100 (24):e26377',
#                    'qualification': 1,
#                    'reportercountry': 'DE'},
#  'primarysourcecountry': 'DE',
#  'receiptdate': datetime.datetime(2024, 1, 23, 0, 0),
#  'receiptdateformat': 102,
#  'receivedate': datetime.datetime(2021, 7, 13, 0, 0),
#  'receivedateformat': 102,
#  'receiver': {'receiverorganization': 'FDA', 'receivertype': 6},
#  'reportduplicate': [{'duplicatenumb': 'DE-PFIZER INC-2021805342',
#                       'duplicatesource': 'PFIZER INC'},
#                      {'duplicatenumb': 'JP-PFIZER INC-PV202400005237',
#                       'duplicatesource': 'PFIZER INC'}],
#  'reporttype': 1,
#  'safetyreportid': 19529532,
#  'safetyreportversion': 2,
#  'sender': {'senderorganization': 'FDA-Public Use', 'sendertype': 2},
#  'serious': 1,
#  'seriousnesscongenitalanomali': 2,
#  'seriousnessdeath': 1,
#  'seriousnessdisabling': 2,
#  'seriousnesshospitalization': 2,
#  'seriousnesslifethreatening': 2,
#  'seriousnessother': 1,
#  'transmissiondate': datetime.datetime(2024, 4, 10, 0, 0),
#  'transmissiondateformat': 102}
# {'_id': ObjectId('68246feda116cc7161242718'),
#  'companynumb': 'US-SA-SAC20210729000884',
#  'duplicate': 1,
#  'fulfillexpeditecriteria': 2,
#  'occurcountry': 'US',
#  'patient': {'drug': [{'actiondrug': 4,
#                        'activesubstance': {'activesubstancename': 'DUPILUMAB'},
#                        'drugadministrationroute': 58,
#                        'drugauthorizationnumb': 761055,
#                        'drugcharacterization': 1,
#                        'drugdosageform': 'Solution for injection',
#                        'drugdosagetext': '300 MG, QOW',
#                        'drugindication': 'Dermatitis atopic',
#                        'drugintervaldosagedefinition': 803,
#                        'drugintervaldosageunitnumb': 2.0,
#                        'drugseparatedosagenumb': 1.0,
#                        'drugstartdate': datetime.datetime(2021, 7, 1, 0, 0),
#                        'drugstartdateformat': 610,
#                        'drugstructuredosagenumb': 300.0,
#                        'drugstructuredosageunit': 3,
#                        'medicinalproduct': 'DUPIXENT',
#                        'openfda': {'application_number': ['BLA761055'],
#                                    'brand_name': ['DUPIXENT'],
#                                    'generic_name': ['DUPILUMAB'],
#                                    'manufacturer_name': ['sanofi-aventis U.S. '
#                                                          'LLC'],
#                                    'nui': ['N0000193342',
#                                            'N0000193341',
#                                            'M0001357'],
#                                    'package_ndc': ['0024-5914-00',
#                                                    '0024-5914-01',
#                                                    '0024-5914-20',
#                                                    '0024-5914-02',
#                                                    '0024-5918-00',
#                                                    '0024-5918-01',
#                                                    '0024-5918-20',
#                                                    '0024-5918-02',
#                                                    '0024-5915-00',
#                                                    '0024-5915-02',
#                                                    '0024-5915-01',
#                                                    '0024-5915-20',
#                                                    '0024-5919-00',
#                                                    '0024-5919-02',
#                                                    '0024-5919-01',
#                                                    '0024-5919-20',
#                                                    '0024-5911-00',
#                                                    '0024-5911-02',
#                                                    '0024-5911-01',
#                                                    '0024-5911-20'],
#                                    'pharm_class_cs': ['Antibodies, Monoclonal '
#                                                       '[CS]'],
#                                    'pharm_class_epc': ['Interleukin-4 Receptor '
#                                                        'alpha Antagonist '
#                                                        '[EPC]'],
#                                    'pharm_class_moa': ['Interleukin 4 Receptor '
#                                                        'alpha Antagonists '
#                                                        '[MoA]'],
#                                    'product_ndc': ['0024-5911',
#                                                    '0024-5914',
#                                                    '0024-5918',
#                                                    '0024-5915',
#                                                    '0024-5919'],
#                                    'product_type': ['HUMAN PRESCRIPTION DRUG'],
#                                    'route': ['SUBCUTANEOUS'],
#                                    'spl_id': ['acdeeda1-b75b-4207-8a41-d8287ac542e1'],
#                                    'spl_set_id': ['595f437d-2729-40bb-9c62-c8ece1f82780'],
#                                    'substance_name': ['DUPILUMAB'],
#                                    'unii': ['420K487FSG']}}],
#              'patientagegroup': 6,
#              'patientonsetage': 83,
#              'patientonsetageunit': 801,
#              'patientsex': 1,
#              'reaction': [{'reactionmeddrapt': 'Erythema',
#                            'reactionmeddraversionpt': 26.1,
#                            'reactionoutcome': 6},
#                           {'reactionmeddrapt': 'Rash',
#                            'reactionmeddraversionpt': 26.1,
#                            'reactionoutcome': 6},
#                           {'reactionmeddrapt': 'Inappropriate schedule of '
#                                                'product administration',
#                            'reactionmeddraversionpt': 26.1,
#                            'reactionoutcome': 6}],
#              'summary': {'case_event_date_extracted': datetime.datetime(2021, 12, 9, 0, 0),
#                          'narrativeincludeclinical': 'CASE EVENT DATE: '
#                                                      '20211209'}},
#  'primarysource': {'qualification': 1, 'reportercountry': 'US'},
#  'primarysourcecountry': 'US',
#  'receiptdate': datetime.datetime(2024, 2, 1, 0, 0),
#  'receiptdateformat': 102,
#  'receivedate': datetime.datetime(2021, 8, 3, 0, 0),
#  'receivedateformat': 102,
#  'receiver': {'receiverorganization': 'FDA', 'receivertype': 6},
#  'reportduplicate': [{'duplicatenumb': 'US-SA-SAC20220107000855',
#                       'duplicatesource': 'SA'},
#                      {'duplicatenumb': 'SanofiPVPortal20220107000279',
#                       'duplicatesource': 'PORTAL ID'},
#                      {'duplicatenumb': 'AE00539448',
#                       'duplicatesource': 'AE Record ID'},
#                      {'duplicatenumb': 'US-SA-SAC20210729000884',
#                       'duplicatesource': 'SA'},
#                      {'duplicatenumb': 'SanofiPVPortal20210728000780',
#                       'duplicatesource': 'PORTAL ID'},
#                      {'duplicatenumb': 'SanofiPVPortal20240122000551',
#                       'duplicatesource': 'PORTAL ID'}],
#  'reporttype': 1,
#  'safetyreportid': 19652409,
#  'safetyreportversion': 3,
#  'sender': {'senderorganization': 'FDA-Public Use', 'sendertype': 2},
#  'serious': 2,
#  'seriousnesscongenitalanomali': 2,
#  'seriousnessdeath': 2,
#  'seriousnessdisabling': 2,
#  'seriousnesshospitalization': 2,
#  'seriousnesslifethreatening': 2,
#  'seriousnessother': 2,
#  'transmissiondate': datetime.datetime(2024, 4, 9, 0, 0),
#  'transmissiondateformat': 102}
# {'_id': ObjectId('68246feda116cc7161242719'),
#  'companynumb': 'US-SA-SAC20210827000741',
#  'duplicate': 1,
#  'fulfillexpeditecriteria': 2,
#  'occurcountry': 'US',
#  'patient': {'drug': [{'actiondrug': 5,
#                        'activesubstance': {'activesubstancename': 'DUPILUMAB'},
#                        'drugadditional': 3,
#                        'drugadministrationroute': 58,
#                        'drugauthorizationnumb': 761055,
#                        'drugcharacterization': 1,
#                        'drugdosageform': 'Solution for injection',
#                        'drugdosagetext': '300 MG, QOW',
#                        'drugindication': 'Dermatitis atopic',
#                        'drugintervaldosagedefinition': 803,
#                        'drugintervaldosageunitnumb': 2.0,
#                        'drugseparatedosagenumb': 1.0,
#                        'drugstructuredosagenumb': 300.0,
#                        'drugstructuredosageunit': 3,
#                        'medicinalproduct': 'DUPIXENT',
#                        'openfda': {'application_number': ['BLA761055'],
#                                    'brand_name': ['DUPIXENT'],
#                                    'generic_name': ['DUPILUMAB'],
#                                    'manufacturer_name': ['sanofi-aventis U.S. '
#                                                          'LLC'],
#                                    'nui': ['N0000193342',
#                                            'N0000193341',
#                                            'M0001357'],
#                                    'package_ndc': ['0024-5914-00',
#                                                    '0024-5914-01',
#                                                    '0024-5914-20',
#                                                    '0024-5914-02',
#                                                    '0024-5918-00',
#                                                    '0024-5918-01',
#                                                    '0024-5918-20',
#                                                    '0024-5918-02',
#                                                    '0024-5915-00',
#                                                    '0024-5915-02',
#                                                    '0024-5915-01',
#                                                    '0024-5915-20',
#                                                    '0024-5919-00',
#                                                    '0024-5919-02',
#                                                    '0024-5919-01',
#                                                    '0024-5919-20',
#                                                    '0024-5911-00',
#                                                    '0024-5911-02',
#                                                    '0024-5911-01',
#                                                    '0024-5911-20'],
#                                    'pharm_class_cs': ['Antibodies, Monoclonal '
#                                                       '[CS]'],
#                                    'pharm_class_epc': ['Interleukin-4 Receptor '
#                                                        'alpha Antagonist '
#                                                        '[EPC]'],
#                                    'pharm_class_moa': ['Interleukin 4 Receptor '
#                                                        'alpha Antagonists '
#                                                        '[MoA]'],
#                                    'product_ndc': ['0024-5911',
#                                                    '0024-5914',
#                                                    '0024-5918',
#                                                    '0024-5915',
#                                                    '0024-5919'],
#                                    'product_type': ['HUMAN PRESCRIPTION DRUG'],
#                                    'route': ['SUBCUTANEOUS'],
#                                    'spl_id': ['acdeeda1-b75b-4207-8a41-d8287ac542e1'],
#                                    'spl_set_id': ['595f437d-2729-40bb-9c62-c8ece1f82780'],
#                                    'substance_name': ['DUPILUMAB'],
#                                    'unii': ['420K487FSG']}}],
#              'patientagegroup': 5,
#              'patientsex': 1,
#              'reaction': [{'reactionmeddrapt': 'Abnormal weight gain',
#                            'reactionmeddraversionpt': 26.1,
#                            'reactionoutcome': 6}]},
#  'primarysource': {'qualification': 1, 'reportercountry': 'US'},
#  'primarysourcecountry': 'US',
#  'receiptdate': datetime.datetime(2024, 3, 26, 0, 0),
#  'receiptdateformat': 102,
#  'receivedate': datetime.datetime(2021, 9, 1, 0, 0),
#  'receivedateformat': 102,
#  'receiver': {'receiverorganization': 'FDA', 'receivertype': 6},
#  'reportduplicate': [{'duplicatenumb': 'US-SA-SAC20210827000741',
#                       'duplicatesource': 'SA'},
#                      {'duplicatenumb': 'SanofiPVPortal20210824000774',
#                       'duplicatesource': 'PORTAL ID'},
#                      {'duplicatenumb': 'US-SA-SAC20240320001243',
#                       'duplicatesource': 'SA'},
#                      {'duplicatenumb': 'SanofiPVPortal20240319001187',
#                       'duplicatesource': 'PORTAL ID'}],
#  'reporttype': 1,
#  'safetyreportid': 19773719,
#  'safetyreportversion': 2,
#  'sender': {'senderorganization': 'FDA-Public Use', 'sendertype': 2},
#  'serious': 2,
#  'seriousnesscongenitalanomali': 2,
#  'seriousnessdeath': 2,
#  'seriousnessdisabling': 2,
#  'seriousnesshospitalization': 2,
#  'seriousnesslifethreatening': 2,
#  'seriousnessother': 2,
#  'transmissiondate': datetime.datetime(2024, 4, 10, 0, 0),
#  'transmissiondateformat': 102}
# {'_id': ObjectId('68246feda116cc716124271a'),
#  'companynumb': 'US-PUMA BIOTECHNOLOGY, LTD.-2021US001141',
#  'fulfillexpeditecriteria': 2,
#  'occurcountry': 'US',
#  'patient': {'drug': [{'actiondrug': 5,
#                        'activesubstance': {'activesubstancename': 'NERATINIB'},
#                        'drugadditional': 3,
#                        'drugadministrationroute': 65,
#                        'drugauthorizationnumb': 208051,
#                        'drugcharacterization': 1,
#                        'drugdosagetext': 'UNK, DAILY',
#                        'drugindication': 'HER2 positive breast cancer',
#                        'drugintervaldosagedefinition': 804,
#                        'drugintervaldosageunitnumb': 1.0,
#                        'drugrecurreadministration': 3,
#                        'drugseparatedosagenumb': 1.0,
#                        'drugstartdate': datetime.datetime(2021, 2, 2, 0, 0),
#                        'drugstartdateformat': 102,
#                        'medicinalproduct': 'NERLYNX',
#                        'openfda': {'application_number': ['NDA208051'],
#                                    'brand_name': ['NERLYNX'],
#                                    'generic_name': ['NERATINIB'],
#                                    'manufacturer_name': ['Puma Biotechnology, '
#                                                          'Inc.'],
#                                    'package_ndc': ['70437-240-18',
#                                                    '70437-240-26',
#                                                    '70437-240-33'],
#                                    'product_ndc': ['70437-240'],
#                                    'product_type': ['HUMAN PRESCRIPTION DRUG'],
#                                    'route': ['ORAL'],
#                                    'rxcui': ['1940648', '1940654'],
#                                    'spl_id': ['1484ac4d-7db5-fd0e-e063-6394a90a2b17'],
#                                    'spl_set_id': ['d1e41dcf-e82a-47c2-a0ad-6c6eef621834'],
#                                    'substance_name': ['NERATINIB MALEATE '
#                                                       'ANHYDROUS'],
#                                    'unii': ['9RM7XY23ZS']}}],
#              'reaction': [{'reactionmeddrapt': 'Diarrhoea',
#                            'reactionmeddraversionpt': 26.1,
#                            'reactionoutcome': 1}],
#              'summary': {'case_event_date_extracted': datetime.datetime(2021, 2, 1, 0, 0),
#                          'narrativeincludeclinical': 'CASE EVENT DATE: '
#                                                      '20210201'}},
#  'primarysource': {'qualification': 3, 'reportercountry': 'US'},
#  'primarysourcecountry': 'US',
#  'receiptdate': datetime.datetime(2024, 3, 6, 0, 0),
#  'receiptdateformat': 102,
#  'receivedate': datetime.datetime(2021, 9, 2, 0, 0),
#  'receivedateformat': 102,
#  'receiver': {'receiverorganization': 'FDA', 'receivertype': 6},
#  'reporttype': 1,
#  'safetyreportid': 19779685,
#  'safetyreportversion': 2,
#  'sender': {'senderorganization': 'FDA-Public Use', 'sendertype': 2},
#  'serious': 2,
#  'seriousnesscongenitalanomali': 2,
#  'seriousnessdeath': 2,
#  'seriousnessdisabling': 2,
#  'seriousnesshospitalization': 2,
#  'seriousnesslifethreatening': 2,
#  'seriousnessother': 2,
#  'transmissiondate': datetime.datetime(2024, 4, 9, 0, 0),
#  'transmissiondateformat': 102}

# %% [markdown]
# ## 3. Verify date normalization

# %%
query = {"drug.drugstartdate": {"$type": "date"}}
docs = list(collection.find(query).limit(5))
for doc in docs:
    pprint(doc["drug"][0]["drugstartdate"])

# %% [markdown]
# ## 4. Check that oversized reports were skipped (logged to file)

# %%
with open("skipped_reports.log", "r") as f:
    skipped = f.readlines()
print(f"Total oversized reports skipped: {len(skipped)}")
print("First few entries:")
print("".join(skipped[:3]))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 with open("skipped_reports.log", "r") as f:
#       2     skipped = f.readlines()
#       3 print(f"Total oversized reports skipped: {len(skipped)}")
#
# File ~\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'skipped_reports.log'
